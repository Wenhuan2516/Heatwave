# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline
import seaborn as sn

# %%
import geopandas as gpd
import pandas as pd

# Load the Shapefile
gdf = gpd.read_file('/global/cfs/cdirs/m1532/Projects_MVP/geospatial/enviorment/Suicide_new/cb_2018_us_county_500k.shp')

# Convert the GeoDataFrame to a DataFrame
df = pd.DataFrame(gdf)

# %%
df
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME LSAD
# 0         21      007  00516850  0500000US21007  21007    Ballard   06  \
# 1         21      017  00516855  0500000US21017  21017    Bourbon   06
# 2         21      031  00516862  0500000US21031  21031     Butler   06
# 3         21      065  00516879  0500000US21065  21065     Estill   06
# 4         21      069  00516881  0500000US21069  21069    Fleming   06
# ...      ...      ...       ...             ...    ...        ...  ...
# 3228      31      073  00835858  0500000US31073  31073     Gosper   06
# 3229      39      075  01074050  0500000US39075  39075     Holmes   06
# 3230      48      171  01383871  0500000US48171  48171  Gillespie   06
# 3231      55      079  01581100  0500000US55079  55079  Milwaukee   06
# 3232      26      139  01623012  0500000US26139  26139     Ottawa   06
#
#            ALAND      AWATER
# 0      639387454    69473325  \
# 1      750439351     4829777
# ...

# %%
len(df['GEOID'].unique())
# Out:
# 3233

# %%
# Load the Shapefile
gdf = gpd.read_file('/global/cfs/cdirs/m1532/Projects_MVP/geospatial/climate_heatwave/gz_2010_us_050_00_500k.shp')

# Convert the GeoDataFrame to a DataFrame
df = pd.DataFrame(gdf)

# %%
df
# Out:
#               GEO_ID STATE COUNTY           NAME    LSAD  CENSUSAREA
# 0     0500000US01029    01    029       Cleburne  County     560.100  \
# 1     0500000US01031    01    031         Coffee  County     678.972
# 2     0500000US01037    01    037          Coosa  County     650.926
# 3     0500000US01039    01    039      Covington  County    1030.456
# 4     0500000US01041    01    041       Crenshaw  County     608.840
# ...              ...   ...    ...            ...     ...         ...
# 3216  0500000US72131    72    131  San Sebastián    Muno      70.423
# 3217  0500000US72133    72    133   Santa Isabel    Muno      34.023
# 3218  0500000US72137    72    137       Toa Baja    Muno      23.241
# 3219  0500000US72139    72    139  Trujillo Alto    Muno      20.764
# 3220  0500000US72153    72    153          Yauco    Muno      68.192
#
#                                                geometry
# 0     POLYGON ((-85.38872 33.91304, -85.38088 33.873...
# ...

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import pandas as pd
import plotly.express as px

# %%
import geopandas as gpd
import pandas as pd

# Load the Shapefile
gdf = gpd.read_file('CityBoundaries/CityBoundaries.shp')

# Convert the GeoDataFrame to a DataFrame
df = pd.DataFrame(gdf)

# %%
df
# Out:
#            NAME            CLASS  ST STFIPS PLACEFIPS  POP2010 STPLFIPS
# 0         Pharr             city  TX     48     57200    70400  4857200  \
# 1       McAllen             city  TX     48     45384   129877  4845384
# 2      Edinburg             city  TX     48     22660    77100  4822660
# 3        Laredo             city  TX     48     41464   236091  4841464
# 4       Mission             city  TX     48     48768    77058  4848768
# ..          ...              ...  ..    ...       ...      ...      ...
# 495    St. Paul             city  MN     27     58000   285068  2758000
# 496   Green Bay             city  WI     55     31000   104057  5531000
# 497  Burlington             city  VT     50     10675    42417  5010675
# 498   Anchorage     municipality  AK     02     03000   291826  0203000
# 499    Honolulu  city and county  HI     15     15003   953207    15003
#
#                                               geometry
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv('CityBoundaries.csv', index=False)

# %%
city = ddf.read_csv("CityBoundaries.csv").compute()
city.head()
# Out:
#        NAME CLASS  ST  STFIPS  PLACEFIPS  POP2010  STPLFIPS
# 0     Pharr  city  TX      48      57200    70400   4857200  \
# 1   McAllen  city  TX      48      45384   129877   4845384
# 2  Edinburg  city  TX      48      22660    77100   4822660
# 3    Laredo  city  TX      48      41464   236091   4841464
# 4   Mission  city  TX      48      48768    77058   4848768
#
#                                             geometry
# 0  POLYGON ((-10929531.2388 3029892.7181, -109294...
# 1  POLYGON ((-10934477.7206 3037591.9565000013, -...
# 2  POLYGON ((-10924696.7425 3050068.458799999, -1...
# 3  POLYGON ((-11090500.3785 3205304.5537, -110903...
# 4  POLYGON ((-10946610.1 3030967.742800001, -1094...

# %%
city = city.sort_values('POP2010', ascending = False)
city
# Out:
#              NAME CLASS  ST  STFIPS  PLACEFIPS  POP2010  STPLFIPS
# 93       New York  city  NY      36      51000  8175133   3651000  \
# 384   Los Angeles  city  CA       6      44000  3792621    644000
# 213       Chicago  city  IL      17      14000  2695598   1714000
# 13        Houston  city  TX      48      35000  2099451   4835000
# 105  Philadelphia  city  PA      42      60000  1526006   4260000
# ..            ...   ...  ..     ...        ...      ...       ...
# 146     Rock Hill  city  SC      45      61405    66154   4561405
# 83    Schenectady  city  NY      36      65508    66135   3665508
# 297      Cheyenne  city  WY      56      13900    59466   5613900
# 153    Charleston  city  WV      54      14600    51400   5414600
# 497    Burlington  city  VT      50      10675    42417   5010675
#
#                                               geometry
# 93   MULTIPOLYGON (((-8260174.664100001 4950523.734...
# 384  MULTIPOLYGON (((-13162830.3816 3996851.7908999...
# ...

# %%
city.head(60)
# Out:
#                  NAME                         CLASS  ST  STFIPS  PLACEFIPS
# 93           New York                          city  NY      36      51000  \
# 384       Los Angeles                          city  CA       6      44000
# 213           Chicago                          city  IL      17      14000
# 13            Houston                          city  TX      48      35000
# 105      Philadelphia                          city  PA      42      60000
# 359           Phoenix                          city  AZ       4      55000
# 5         San Antonio                          city  TX      48      65000
# 324         San Diego                          city  CA       6      66000
# 264            Dallas                          city  TX      48      19000
# 499          Honolulu               city and county  HI      15      15003
# 460          San Jose                          city  CA       6      68000
# ...

# %%
city_list = city['NAME'].to_list()

# %%
string_to_check = 'Birmingham'

if string_to_check in city_list:
    print('The string is in the list.')
else:
    print('The string is not in the list.')
# Out:
# The string is in the list.

# %%
dict_city = {'Seattle': 1, 'Portland': 2, 'San Francisco': 3, 'Fresno': 4, 'Los Angeles': 5, 'San Diego': 6, 'Las Vegas': 7, 'Salt Lake City': 8, 
             'Phoenix': 9, 'Tucson': 10, 'Albuquerque': 11, 'El Paso': 12, 'Oklahoma City': 13, 'San Antonio': 14, 'Tulsa': 15, 'Fort Worth': 16, 
             'Austin': 17, 'Baton Rouge': 18, 'New Orleans': 19, 'Birmingham': 20, 'Memphis': 21, 'St. Louis': 22, 'Indianapolis': 23, 'Chicago': 24,
             'Milwaukee': 25, 'Detroit': 26, 'Dayton': 27, 'Louisville': 28, 'Nashville': 29, 'Atlanta': 30, 'Tampa':31, 'Miami': 32, 'Jacksonville': 33,
             'Columbia': 34, 'Raleigh': 35, 'Greensboro': 36, 'Baltimore': 37, 'Richmond': 38, 'Columbus':39, 'Pittsburgh': 40, 'Cleveland': 41, 
             'Allentown': 42, 'Albany': 43, 'Boston': 44, 'Providence': '45', 'Hartford': 46, 'Buffalo': 47, 'Rochester': 48, 'Philadelphia': 49, 
             'Charlotte': 50}

# %%
city_50 = pd.DataFrame(list(dict_city.items()), columns=['City', 'Number'])

city_50
# Out:
#               City Number
# 0          Seattle      1
# 1         Portland      2
# 2    San Francisco      3
# 3           Fresno      4
# 4      Los Angeles      5
# 5        San Diego      6
# 6        Las Vegas      7
# 7   Salt Lake City      8
# 8          Phoenix      9
# 9           Tucson     10
# 10     Albuquerque     11
# 11         El Paso     12
# 12   Oklahoma City     13
# 13     San Antonio     14
# 14           Tulsa     15
# 15      Fort Worth     16
# 16          Austin     17
# 17     Baton Rouge     18
# 18     New Orleans     19
# 19      Birmingham     20
# 20         Memphis     21
# 21       St. Louis     22
# 22    Indianapolis     23
# 23         Chicago     24
# 24       Milwaukee     25
# 25         Detroit     26
# 26          Dayton     27
# 27      Louisville     28
# 28       Nashville     29
# 29         Atlanta     30
# 30           Tampa     31
# 31           Miami     32
# 32    Jacksonville     33
# 33        Columbia     34
# ...

# %%
city_50 = city_50.rename(columns = {'City': 'NAME'})
city_50 = city_50.merge(city, on = ['NAME'], how = 'left')
city_50
# Out:
#               NAME Number                         CLASS  ST  STFIPS
# 0          Seattle      1                          city  WA      53  \
# 1         Portland      2                          city  OR      41
# 2         Portland      2                          city  ME      23
# 3    San Francisco      3                          city  CA       6
# 4           Fresno      4                          city  CA       6
# 5      Los Angeles      5                          city  CA       6
# 6        San Diego      6                          city  CA       6
# 7        Las Vegas      7                          city  NV      32
# 8   Salt Lake City      8                          city  UT      49
# 9          Phoenix      9                          city  AZ       4
# 10          Tucson     10                          city  AZ       4
# 11     Albuquerque     11                          city  NM      35
# 12         El Paso     12                          city  TX      48
# ...

# %%
city_50.to_csv('50_city_boundaries.csv')
